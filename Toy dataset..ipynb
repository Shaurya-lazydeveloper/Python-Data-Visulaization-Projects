# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\Shaurya Tiwari\OneDrive\Desktop\python\Projects on Data Analysis\Data Set CSV\toy_dataset.csv")
del df['Number']
df.head(20)
# Out:
#       City  Gender  Age   Income Illness
# 0   Dallas    Male   41  40367.0      No
# 1   Dallas    Male   54  45084.0      No
# 2   Dallas    Male   42  52483.0      No
# 3   Dallas    Male   40  40941.0      No
# 4   Dallas    Male   46  50289.0      No
# 5   Dallas  Female   36  50786.0      No
# 6   Dallas  Female   32  33155.0      No
# 7   Dallas    Male   39  30914.0      No
# 8   Dallas    Male   51  68667.0      No
# 9   Dallas  Female   30  50082.0      No
# 10  Dallas  Female   48  41524.0     Yes
# 11  Dallas    Male   47  54777.0      No
# 12  Dallas    Male   46  62749.0      No
# 13  Dallas  Female   42  50894.0      No
# 14  Dallas  Female   61  38429.0      No
# 15  Dallas    Male   43  34074.0      No
# 16  Dallas    Male   27  50398.0      No
# 17  Dallas    Male   38  46373.0     Yes
# 18  Dallas    Male   47  51137.0      No
# 19  Dallas  Female   35  23688.0      No

# %% [markdown]
# ### Some stats about this data

# %%
df.describe()
# Out:
#                  Age         Income
# count  150000.000000  150000.000000
# mean       44.950200   91252.798273
# std        11.572486   24989.500948
# min        25.000000    -654.000000
# 25%        35.000000   80867.750000
# 50%        45.000000   93655.000000
# 75%        55.000000  104519.000000
# max        65.000000  177157.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   City     150000 non-null  object
#  1   Gender   150000 non-null  object
#  2   Age      150000 non-null  int64
#  3   Income   150000 non-null  float64
#  4   Illness  150000 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 5.7+ MB

# %%
df.shape
# Out:
# (150000, 5)

# %%
df.columns
# Out:
# Index(['City', 'Gender', 'Age', 'Income', 'Illness'], dtype='object')

# %%
df.dtypes
# Out:
# City        object
# Gender      object
# Age          int64
# Income     float64
# Illness     object
# dtype: object

# %%
df.City.unique()
# Out:
# array(['Dallas', 'New York City', 'Los Angeles', 'Mountain View',
#        'Boston', 'Washington D.C.', 'San Diego', 'Austin'], dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.Illness.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ## Handling with missing values and error

# %%
df.isnull().sum()
# Out:
# City       0
# Gender     0
# Age        0
# Income     0
# Illness    0
# dtype: int64

# %%
is_error = df[df['Income'] < 0]
is_error
# Out:
#        City  Gender  Age  Income Illness
# 245  Dallas  Female   40  -654.0     Yes

# %%
df = df.drop(df.index[245])
df.describe()
# Out:
#                  Age         Income
# count  149999.000000  149999.000000
# mean       44.950233   91253.410989
# std        11.572517   24988.457482
# min        25.000000     584.000000
# 25%        35.000000   80868.000000
# 50%        45.000000   93655.000000
# 75%        55.000000  104519.000000
# max        65.000000  177157.000000

# %% [markdown]
# ## Counting

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Illness', palette='rocket', data=df)
# Out:
# <AxesSubplot:xlabel='Illness', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender', palette='rocket', data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Gender', hue='Illness', palette='rocket', data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Gender", hue="City",palette="rocket", data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="City", hue="Gender",palette="rocket", data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Age'], color='b')
plt.title('Age distribution')
# Out:
# C:\Users\Shaurya Tiwari\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Age distribution')

# %%
plt.figure(figsize=(10,5))
sns.distplot(df["Income"], color='g')
plt.title("Income distribution")
# Out:
# C:\Users\Shaurya Tiwari\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Income distribution')

# %%
plt.figure(figsize=(10,5))
sns.distplot(df[df["Illness"] == "Yes"]["Income"], color="y")
plt.title("Income distribution - Illness:Yes")
# Out:
# Text(0.5, 1.0, 'Income distribution - Illness:Yes')

# %%
plt.figure(figsize=(10,5))
sns.distplot(df[df["Illness"] == "No"]["Income"], color="m")
plt.title("Income distribution - Illness:No")
# Out:
# C:\Users\Shaurya Tiwari\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Income distribution - Illness:No')

# %%
fig = plt.figure(figsize=(10,5))
sns.distplot(df[df["Gender"] == "Male"]["Income"])
sns.distplot(df[df["Gender"] == "Female"]["Income"])
fig.legend(labels=['Male','Female'])
plt.title("Income distribution - Man and Woman")
plt.show()
# Out:
# C:\Users\Shaurya Tiwari\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Shaurya Tiwari\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df['Income'], y=df['City'], data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='City'>

# %% [markdown]
# ## THE END
